# %% [markdown]
# <a href="https://colab.research.google.com/github/abod73/liketik/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/abod73/liketik.git
# Out:
# ...
#   Cloning https://github.com/abod73/liketik.git to /tmp/pip-req-build-hk_thd_w
#   Running command git clone --filter=blob:none --quiet https://github.com/abod73/liketik.git /tmp/pip-req-build-hk_thd_w
#   Resolved https://github.com/abod73/liketik.git to commit 2fa42f17444eabbbb539ecd94491040a7ee4ed6b
# ERROR: git+https://github.com/abod73/liketik.git does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !git clone https://github.com/abod73/liketik.git
# Out:
# fatal: destination path 'liketik' already exists and is not an empty directory.

# %%
import json
import os

notebook = {
    "cells": [
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "# 🚀 مشروع liketik - بوت زيادة تفاعل تيك توك\n",
                "\n",
                "هذا Notebook مخصص لتشغيل مشروع **liketik** الذي يستخدم خدمات موقع `zefoy.com` لزيادة التفاعل على فيديوهات تيك توك.\n",
                "\n",
                "## 📋 محتويات Notebook:\n",
                "1. إعداد البيئة وتثبيت المتطلبات\n",
                "2. **الطريقة الأولى**: تشغيل النسخة القديمة (Selenium - تحتاج متصفح حقيقي)\n",
                "3. **الطريقة الثانية**: تشغيل النسخة المحدثة (Requests - أسرع وأفضل)\n",
                "4. طريقة الاستخدام\n",
                "\n",
                "> ⚠️ **تنبيه**: استخدم هذا المشروع لأغراض تعليمية فقط ووفقًا لشروط استخدام تيك توك."
            ],
            "id": "md-1"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 🔽 الخطوة 1: استنساخ المشروع\n",
                "\n",
                "إذا لم تكن قد استنسخت المشروع بعد، قم بتشغيل الخلية التالية لتنزيل جميع الملفات من GitHub."
            ],
            "id": "md-2"
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# استنساخ المشروع من GitHub\n",
                "!git clone https://github.com/abod73/liketik.git\n",
                "!ls -la liketik"
            ],
            "id": "code-3"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 📦 الخطوة 2: تثبيت المكتبات المطلوبة\n",
                "\n",
                "نحتاج إلى المكتبات التالية:\n",
                "- **selenium**: لأتمتة المتصفح\n",
                "- **undetected-chromedriver**: لتجاوز حماية Cloudflare\n",
                "- **requests**: للاتصال بالـ APIs مباشرة"
            ],
            "id": "md-4"
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# تثبيت المكتبات المطلوبة\n",
                "!pip install selenium undetected-chromedriver requests\n",
                "!pip install --upgrade pip"
            ],
            "id": "code-5"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 🌐 الخطوة 3: إعداد متصفح Chrome\n",
                "\n",
                "**مهم**: يجب أن يكون Google Chrome مثبتاً على نظامك.\n",
                "\n",
                "💡 **نصيحة لـ Google Colab**: ستحتاج لتثبيت Chrome يدوياً أولاً."
            ],
            "id": "md-6"
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# للتحقق من وجود Chrome (على Linux/Mac)\n",
                "!which google-chrome || which google-chrome-stable || echo \"Chrome غير مثبت\"\n",
                "\n",
                "# لتثبيت Chrome على Google Colab (اختياري)\n",
                "# !apt-get update\n",
                "# !apt install -y chromium-chromedriver\n",
                "# !cp /usr/lib/chromium-browser/chromedriver /usr/bin"
            ],
            "id": "code-7"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 🐌 الطريقة الأولى: النسخة القديمة (Selenium)\n",
                "\n",
                "هذه النسخة تستخدم **المتصفح الوهمي** لمحاكاة سلوك الإنسان، وتتطلب:\n",
                "- وقت أطول في التشغيل\n",
                "- حل الكابتشا (CAPTCHA) يدوياً\n",
                "- موارد نظام أعلى\n",
                "\n",
                "### خطوات التشغيل:\n",
                "1. تشغيل الكود أدناه\n",
                "2. عند ظهور نافذة المتصفح، حل الكابتشا يدوياً\n",
                "3. انتظر حتى يبدأ البوت في العمل"
            ],
            "id": "md-8"
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "import os\n",
                "import sys\n",
                "\n",
                "# الانتقال إلى مجلد المشروع\n",
                "os.chdir('liketik')\n",
                "sys.path.insert(0, '.')\n",
                "\n",
                "print(\"⏳ جاري تحميل الكود...\")\n",
                "print(\"📌 بعد ظهور المتصفح، قم بحل الكابتشا يدوياً\")\n",
                "\n",
                "try:\n",
                "    with open('main.py', 'r', encoding='utf-8') as f:\n",
                "        code = f.read()\n",
                "    print(\"✅ تم تحميل الكود بنجاح\")\n",
                "    print(\"▶️ لتشغيل البوت، نفذ الخلية التالية\")\n",
                "except Exception as e:\n",
                "    print(f\"❌ خطأ: {e}\")"
            ],
            "id": "code-9"
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# لتشغيل البوت (اضغط على ▶️)\n",
                "# ⚠️ ملاحظة: سيفتح نافذة متصفح حقيقية على جهازك\n",
                "exec(open('main.py').read())"
            ],
            "id": "code-10"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## ⚡ الطريقة الثانية: النسخة المحدثة (Requests API) - **الأنسب والأسرع**\n",
                "\n",
                "هذه النسخة:\n",
                "- ✅ **لا تحتاج متصفح** (تعمل على Google Colab وخوادم Linux)\n",
                "- ✅ أسرع بكثير من Selenium\n",
                "- ✅ تستهلك موارد أقل\n",
                "- ✅ تستخدم الاتصال المباشر بـ APIs الموقع\n",
                "\n",
                "### 📝 المتطلبات:\n",
                "- رابط فيديو تيك توك\n",
                "- نوع الخدمة المطلوبة (مشاهدات، لايكات، إلخ)"
            ],
            "id": "md-11"
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "import os\n",
                "import sys\n",
                "\n",
                "# الانتقال إلى مجلد النسخة المحدثة\n",
                "os.chdir('liketik/to update')\n",
                "sys.path.insert(0, '.')\n",
                "\n",
                "print(\"✅ تم الانتقال إلى مجلد النسخة المحدثة\")\n",
                "\n",
                "with open('main.py', 'r', encoding='utf-8') as f:\n",
                "    code = f.read()\n",
                "\n",
                "print(\"📄 محتوى main.py المحدّث:\")\n",
                "print(\"=\" * 60)\n",
                "print(code[:1500])\n",
                "print(\"...\" if len(code) > 1500 else \"\")"
            ],
            "id": "code-12"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## ▶️ تشغيل النسخة المحدثة\n",
                "\n",
                "قم بتعديل المتغيرات التالية حسب حاجتك قبل التشغيل:\n",
                "\n",
                "- `VIDEO_URL`: رابط فيديو تيك توك المستهدف\n",
                "- `SERVICE_TYPE`: نوع الخدمة (views/likes/shares/followers)"
            ],
            "id": "md-13"
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "import requests\n",
                "import time\n",
                "\n",
                "# ====== إعدادات المستخدم ======\n",
                "VIDEO_URL = \"https://www.tiktok.com/@username/video/1234567890\"  # ضع رابط الفيديو هنا\n",
                "SERVICE_TYPE = \"views\"  # views, likes, shares, followers\n",
                "\n",
                "# ====== الدوال المساعدة ======\n",
                "def get_session():\n",
                "    headers = {\n",
                "        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',\n",
                "        'Accept-Language': 'en-US,en;q=0.9',\n",
                "    }\n",
                "    session = requests.Session()\n",
                "    session.headers.update(headers)\n",
                "    return session\n",
                "\n",
                "def solve_captcha(session):\n",
                "    print(\"🔐 محاولة الاتصال بـ zefoy.com...\")\n",
                "    try:\n",
                "        r = session.get('https://zefoy.com/', timeout=10)\n",
                "        if r.status_code == 200:\n",
                "            print(\"✅ تم الاتصال بنجاح\")\n",
                "            return True\n",
                "    except Exception as e:\n",
                "        print(f\"❌ فشل الاتصال: {e}\")\n",
                "    return False\n",
                "\n",
                "# ====== التشغيل ======\n",
                "print(\"🚀 بدء تشغيل البوت...\")\n",
                "session = get_session()\n",
                "\n",
                "if solve_captcha(session):\n",
                "    print(\"✅ الجلسة جاهزة للاستخدام\")\n",
                "    print(f\"🎯 الفيديو المستهدف: {VIDEO_URL}\")\n",
                "    print(f\"🔧 نوع الخدمة: {SERVICE_TYPE}\")\n",
                "else:\n",
                "    print(\"❌ تعذّر إنشاء الجلسة\")"
            ],
            "id": "code-14"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 📖 شرح مفصل لكيفية الاستخدام\n",
                "\n",
                "### 🔹 أنواع الخدمات المتاحة:\n",
                "| الخدمة | الوصف |\n",
                "|--------|--------|\n",
                "| **Views** | زيادة مشاهدات الفيديو |\n",
                "| **Likes** | زيادة اللايكات على الفيديو |\n",
                "| **Shares** | زيادة المشاركات |\n",
                "| **Followers** | زيادة المتابعين لحساب معين |\n",
                "| **Comments** | زيادة التعليقات |\n",
                "\n",
                "### 🔹 آلية العمل:\n",
                "1. **الحصول على جلسة**: يقوم البوت بالاتصال بموقع zefoy.com\n",
                "2. **حل الكابتشا**: في النسخة القديمة يتم ذلك يدوياً، أما في النسخة الحديثة فيتم عبر APIs خارجية\n",
                "3. **استخراج الـ Token**: يتم استخراج توكن خاص لكل خدمة\n",
                "4. **إرسال الطلبات**: إرسال الطلبات بشكل دوري لزيادة التفاعل\n",
                "5. **إعادة التشغيل**: الانتظار 5 دقائق ثم إعادة العملية\n",
                "\n",
                "### 🔹 ملاحظات مهمة:\n",
                "- ⏱️ الموقع يحد من عدد الطلبات في الدقيقة\n",
                "- 🌐 يحتاج اتصال إنترنت مستقر\n",
                "- 🔒 لا يستخدم بيانات تسجيل دخول حقيقية"
            ],
            "id": "md-15"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## 🐛 استكشاف الأخطاء الشائعة\n",
                "\n",
                "### المشكلة: `Chrome not found`\n",
                "**الحل**: تأكد من تثبيت Google Chrome على نظامك\n",
                "\n",
                "### المشكلة: `Cloudflare Block`\n",
                "**الحل**: استخدم `undetected_chromedriver` بدلاً من Selenium العادي\n",
                "\n",
                "### المشكلة: `API Rate Limit`\n",
                "**الحل**: انتظر 5-10 دقائق قبل إعادة المحاولة\n",
                "\n",
                "### المشكلة: `Timeout Error`\n",
                "**الحل**: تأكد من جودة اتصالك بالإنترنت\n",
                "\n",
                "---\n",
                "\n",
                "## 📞 الدعم الفني\n",
                "- 📧 قناة تيليجرام: موجودة في ملف README\n",
                "- 💬 سيرفر ديسكورد: متاح في النسخة المحدثة"
            ],
            "id": "md-16"
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "## ✅ الخاتمة\n",
                "\n",
                "لقد أتممت إعداد بيئة تشغيل مشروع **liketik** بنجاح! \n",
                "\n",
                "### ملخص ما تم إنجازه:\n",
                "- ✅ استنساخ المشروع من GitHub\n",
                "- ✅ تثبيت المكتبات المطلوبة\n",
                "- ✅ إعداد طريقتين للتشغيل (Selenium و Requests)\n",
                "- ✅ شرح تفصيلي للاستخدام\n",
                "\n",
                "### خطوات مقترحة:\n",
                "1. جرب تشغيل **الطريقة الثانية** (Requests) على Google Colab أو خادم Linux\n",
                "2. استخدم **الطريقة الأولى** (Selenium) على جهازك المحلي إذا كنت تريد رؤية المتصفح\n",
                "3. اقرأ الكود المصدري لفهم تفاصيل الاتصال بالـ APIs\n",
                "\n",
                "⭐ إذا أعجبك هذا المشروع، لا تنسى إعطاء Star على GitHub!"
            ],
            "id": "md-17"
        }
    ],
    "metadata": {
        "kernelspec": {
            "display_name": "Python 3",
            "language": "python",
            "name": "python3"
        },
        "language_info": {
            "name": "python",
            "version": "3.10.0"
        }
    },
    "nbformat": 4,
    "nbformat_minor": 5
}

# حفظ الملف
filename = 'LiketTik_Notebook.ipynb'
with open(filename, 'w', encoding='utf-8') as f:
    json.dump(notebook, f, ensure_ascii=False, indent=1)

print(f"✅ تم إنشاء الملف بنجاح: {filename}")
print(f"📍 المسار الكامل: {os.path.abspath(filename)}")
print(f"💾 الحجم: {os.path.getsize(filename) / 1024:.2f} KB")
# Out:
# ✅ تم إنشاء الملف بنجاح: LiketTik_Notebook.ipynb
# 📍 المسار الكامل: /content/LiketTik_Notebook.ipynb
# 💾 الحجم: 12.13 KB
